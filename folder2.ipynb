# %%
from PIL import Image
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\Image Processing'

# %%
image1=Image.open("44.jpg")
image1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1E2EF3AF1F0>

# %%
image1.show()

# %%
image1.save("pic1.png")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '11.jpg',
#  '2.jpg',
#  '22.jfif',
#  '3.gif',
#  '3.jpg',
#  '3.tiff',
#  '33.jpg',
#  '41239.jpg',
#  '44.jpg',
#  '55.jpg',
#  '8-12.ipynb',
#  'Adding.ipynb',
#  'Bitwise.ipynb',
#  'blending.ipynb',
#  'cat.png',
#  'cat2.png',
#  'cat_impainted.png',
#  'cat_inpainted2.png',
#  'cat_mask.png',
#  'circle.jpg',
#  'circle1.jpg',
#  'colors.ipynb',
#  'common-kingfisher-dhritiman-mukherjee-1632484087720.webp',
#  'contour.ipynb',
#  'crop.ipynb',
#  'dice.jpg',
#  'Dice2.png',
#  'dice3.jpg',
#  'dices.jpg',
#  'dices1.jpg',
#  'face.jpg',
#  'flower11.jpg',
#  'folder.ipynb',
#  'fruit.jpg',
#  'gfgblack.png',
#  'gfg_white.png',
#  'histogram.ipynb',
#  'horse.jpg',
#  'imag.jpg',
#  'img.jpg',
#  'img2.jpg',
#  'Jaguar-stream-Brazil.webp',
#  'lab(classroom).ipynb',
#  'Lab1.ipynb',
#  'Lab2.ipynb',
#  'lion-Kenya-Masai-Mara-National-Reserve.webp',
#  'listout_images.ipynb',
#  'logo.png',
#  'montage.ipynb',
#  'new.jpg',
#  'noise.png',
#  'pic1.png',
#  'quantization.ipynb',
#  'raccoon.png',
#  'remove_obj.ipynb',
#  'Resize.ipynb',
#  'RGB.ipynb',
#  'scaled.png',
#  'square.jpg',
#  'square1.jpg',
#  'taj.png',
#  'tesla.csv',
#  'text_removed_image.jpg',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled10.ipynb',
#  'Untitled11.ipynb',
#  'Untitled12.ipynb',
#  'Untitled13.ipynb',
#  'Untitled14.ipynb',
#  'Untitled15.ipynb',
#  'Untitled16.ipynb',
#  'Untitled17.ipynb',
#  'Untitled2.ipynb',
#  'Untitled3.ipynb',
#  'Untitled4.ipynb',
#  'Untitled5.ipynb',
#  'Untitled6.ipynb',
#  'Untitled7.ipynb',
#  'Untitled8.ipynb',
#  'Untitled9.ipynb',
#  'upsampling.ipynb',
#  'watermark1.jpg',
#  'writing.ipynb']

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i=Image.open(f)
        fn, fext=os.path.splitext(f)
        print(fn, "&", fext)
# Out:
# 11 & .jpg
# 2 & .jpg
# 3 & .jpg
# 33 & .jpg
# 41239 & .jpg
# 44 & .jpg
# 55 & .jpg
# circle & .jpg
# circle1 & .jpg
# dice & .jpg
# dice3 & .jpg
# dices & .jpg
# dices1 & .jpg
# face & .jpg
# flower11 & .jpg
# fruit & .jpg
# horse & .jpg
# imag & .jpg
# img & .jpg
# img2 & .jpg
# new & .jpg
# square & .jpg
# square1 & .jpg
# text_removed_image & .jpg
# watermark1 & .jpg

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        print(f)
# Out:
# 11.jpg
# 2.jpg
# 3.jpg
# 33.jpg
# 41239.jpg
# 44.jpg
# 55.jpg
# circle.jpg
# circle1.jpg
# dice.jpg
# dice3.jpg
# dices.jpg
# dices1.jpg
# face.jpg
# flower11.jpg
# fruit.jpg
# horse.jpg
# imag.jpg
# img.jpg
# img2.jpg
# new.jpg
# square.jpg
# square1.jpg
# text_removed_image.jpg
# watermark1.jpg

# %%
os.mkdir('NewExt')

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i=Image.open(f)
        fn, fext=os.path.splitext(f)
        i.save("NewExt/{}.pdf".format(fn))

# %%
#Resize

# %%
os.makedirs('resize//small3')
os.makedirs('resize//tiny3')

# %%
size_small = (600,600) # small images of 600 X 600 pixels
size_tiny = (200,200)  # tiny images of 200 X 200 pixels
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i = Image.open(f)
        fn, fext = os.path.splitext(f)
        i.thumbnail(size_small)
        i.save("resize/small/{}_small{}".format(fn, fext))
        i.thumbnail(size_tiny)
        i.save("resize/tiny/{}_tiny{}".format(fn, fext))

# %%
image2=Image.open("44.jpg")
image2=image2.convert(mode='L')
image2
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x1E2F0620CA0>

# %%
os.mkdir('b&w')

# %%
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i=Image.open(f)
        fn, fext=os.path.splitext(f)
        im=i.convert(mode="L")
        im.save("b&w/{}_bw.{}".format(fn,fext))

# %%
image3=Image.open("44.jpg")
image3.rotate(55).save("image3.jpg")
image3=Image.open("image3.jpg")

# %%
image3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1E2F0711A30>

# %%
os.mkdir('rotate')
for f in os.listdir("."):
    if f.endswith(".jpg"):
        i=Image.open(f)
        fn, fext=os.path.splitext(f)
        im=i.rotate(90)
        im.save("rotate/{}_rot.{}".format(fn, fext))
