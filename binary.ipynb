# %%
import cv2
import numpy as np
from PIL import Image
img=cv2.imread('C:/Users/User/Downloads/img.jpg')
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# <function destroyAllWindows>

# %%
img2=Image.open('C:/Users/User/Downloads/img.jpg')
width=img2.width
height=img2.height
print("height:",height)
print("width:",width)
# Out:
# height: 354
# width: 630

# %%
image=cv2.imread("img.jpg")
print("no of channels is:"+str(image.ndim))
print("no of channels is:",image.shape)
cv2.imshow('images',image)
cv2.waitKey(0)
cv2.destroyAllWindows
# Out:
# no of channels is:3
# no of channels is: (354, 630, 3)
# <function destroyAllWindows>

# %%
import matplotlib.image as image
img3=image.imread("3.jpg")
print('shape',img3.shape)
print("array")
print(img3)
# Out:
# shape (600, 600, 3)
# array
# [[[ 99 106 132]
#   [102 110 133]
#   [102 108 130]
#   ...
#   [ 45  66  83]
#   [ 53  74  91]
#   [ 63  86 104]]
#
#  [[ 95 104 121]
#   [ 94 103 118]
#   [ 90  97 113]
#   ...
#   [ 70  92 113]
#   [ 67  92 112]
#   [ 65  90 112]]
#
#  [[ 83  93 102]
#   [ 82  92 101]
#   [ 79  89  98]
#   ...
#   [ 83 108 130]
#   [ 76 100 124]
#   [ 67  91 115]]
#
#  ...
#
#  [[ 24  50  77]
#   [ 24  50  77]
#   [ 25  50  80]
#   ...
#   [ 44  70 107]
#   [ 41  67 104]
#   [ 37  63 100]]
#
#  [[ 28  54  81]
#   [ 26  52  79]
#   [ 25  49  77]
#   ...
#   [ 36  62  99]
#   [ 38  64 101]
#   [ 41  67 102]]
#
#  [[ 32  56  84]
#   [ 30  54  82]
#   [ 27  51  79]
#   ...
#   [ 39  65 100]
#   [ 36  62  97]
#   [ 33  57  93]]]

# %%
from PIL import Image
filepath="3.jpg"
im=Image.open(filepath)
new_im=im.resize((400,400))
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x26D02260730>

# %%
import cv2
img=cv2.imread("3.jpg",0)
ret, bw_img=cv2.threshold(img,127,225,cv2.THRESH_BINARY)
bw=cv2.threshold(img,225,127,cv2.THRESH_BINARY)
cv2.imshow("BINARY",bw_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
